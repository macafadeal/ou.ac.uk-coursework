# %% [markdown]
# <a name="cellTowers"></a>
# # Activity 6.16 - Cell Tower Lookup
#
# Online web applications such as [OpenCelliD](https://www.opencellid.org/) allow users to enter uniquely identifying information for a cell tower and in return display the location of the corresponding cell tower on an interactive map.
#
# For example, use the above service to identify the location of the cell tower with details:
#
# - MCC: 234
# - MNC: 15
# - LAC: 24708
# - CID: 2561566
#
# Services such as OpenCellID typically obtain the location data by calling a remote geolocation web service via an Application Programming Interface (API). With access to such an API, we can create our own equivalent service.
#
# In this activity you will see how to call the API services *in principle*, if not in fact.

# %% [markdown]
# ## Walk-through of How to Call the API
#
# If you use your browser developer tools to monitor your browser's network activity as you lookup a cell tower ID using the OpenCellID webservice, you might notice a request is made to a webservice that is used to lookup the location of the cell tower :
#
# ![OpenCellID website - API call for cell tower geolocation from cell tower identifying data](images/OpenCelliD_api_call.png)
#
# The request URL has the form:
#
# `https://opencellid.org/ajax/searchCell.php?mcc=234&mnc=15&lac=24708&cell_id=2561566`
#
# The location information is then used by calls to other services that can render the map, along with the location of cell towers in that general area.

# %% [markdown]
# The following walk through demonstrates the steps used to make a request to that API.
#
# *Note that the following activity cannot be guaranteed to work. Webservices and APIs often use cookies and other techniques to block requests that are not made by an authorised user from an appropriate client (such as a web browser).*

# %% [markdown]
# To call the API, or look up a cell tower location using a third party web app with its own API access, we need four pieces of data:
#
# - the network operator mobile country code (MCC): for example, the UK MCC code is 234
# - the mobile network code (MNC): for example, the Vodafone UK MNC is 15
# - the cell tower location area code (LAC): for example, 24708
# - the cell tower cell ID (CellID): for example, 2561566
#
# To call the service, we construct a URL as defined for a particular API and make a request to that URL using the *python* `requests` package.

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# The requests library makes it easy to call URLs using Python
import requests

# %% [markdown]
# To pass the data to the API, we need to create a Python `dict` that describes the data in a formally structured way:

# %%
params = {
    "mcc": 234,  # mobileCountryCode
    "mnc": 15,  # mobileNetworkCode
    "lac": 24708,  # locationAreaCode
    "cell_id": 2561566,  # CellId
}

params
# Out:
# {'mcc': 234, 'mnc': 15, 'lac': 24708, 'cell_id': 2561566}

# %% [markdown]
# This parameter data is passed, as part of an HTTP/POST request, to the API endpoint URL using the `requests` package.
#
# The `requests` package also allows us parse any valid response as a JSON object and cast it to a Python dictionary:

# %%
import requests

# The API request may not be satisfied in a JupyterLite environment
try:
    # Set the url to the appropriate API endpoint location
    url = "https://opencellid.org/ajax/searchCell.php"

    r = requests.get(url, params=params)
    if not r.ok:
        # display the response if something went wrong...
        print("Error: " + r.text)

    # Display the response
    response_data = r.json()
except:
    # So provide some dummy data
    print("Using dummy response data...")
    response_data = {"lon": "-1.145837", "lat": "50.657593", "range": "1000"}

response_data
# Out:
# {'lon': -1.200002, 'lat': 50.652477, 'range': 1000}

# %% [markdown]
# A typical response looks something like this:
#
# ```json
# {"lon": "-1.145837", "lat": "50.657593", "range": "1000"}
# ```
#
# If the location of the devices with the specified MAC addresses are known, a location is determined and returned .
#
# The latitude / longitude pair can then be used to identify the approximate location on a map.
#
# For example, let's extract out the latitude and longitude into some correspondingly named variables:

# %%
lon = response_data["lon"]
lat = response_data["lat"]

# The values are parsed as strings
lon, lat
# Out:
# (-1.200002, 50.652477)

# %% [markdown]
# ## So Where is That Location Exactly?
#
# Armed with the latitude and longitude of a location, we can use those co-ordinates to place a marker on a map to reveal that location in more human understandable terms.
#
# A quick way of doing that is to use some magic, literally, using some IPython magic known as `ipython_folium_magic` [[docs](https://github.com/psychemedia/ipython_magic_folium)]...
#
# The following code cell loads in some IPython magic that supports the creation of embedded Google Maps in a Jupyter notebook. This cell only needs to be run once in any given notebook. Typically, magics are loaded at the start of a notebook, along with required Python packages.

# %%
# %pip install folium-magic
# Out:
# ERROR: Could not find a version that satisfies the requirement folium-magic (from versions: none)
# ERROR: No matching distribution found for folium-magic
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install folium
# Out:
# Requirement already satisfied: folium in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from folium) (2.5.2)
# Requirement already satisfied: requests in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from folium) (2.34.2)
# Requirement already satisfied: xyzservices in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from folium) (2026.9.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->folium) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->folium) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->folium) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --no-deps git+https://github.com/psychemedia/ipython_magic_folium.git
# Out:
# Collecting git+https://github.com/psychemedia/ipython_magic_folium.git
#   Cloning https://github.com/psychemedia/ipython_magic_folium.git to /private/var/folders/ph/_t786pjj2wd05kq_3p1rvh380000gn/T/pip-req-build-h8mk4fyi
#   Running command git clone --filter=blob:none --quiet https://github.com/psychemedia/ipython_magic_folium.git /private/var/folders/ph/_t786pjj2wd05kq_3p1rvh380000gn/T/pip-req-build-h8mk4fyi
#   Resolved https://github.com/psychemedia/ipython_magic_folium.git to commit a34810d7c404bc542c84fac485b7db10e8da1ccf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas geojson
# Out:
# Requirement already satisfied: pandas in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (3.0.5)
# Requirement already satisfied: geojson in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (3.3.0)
# Requirement already satisfied: numpy>=2.3.3 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !brew install gdal

# %%
# %pip install fiona
# Out:
# Requirement already satisfied: fiona in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (1.10.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from fiona) (26.1.0)
# Requirement already satisfied: certifi in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from fiona) (2026.7.22)
# Requirement already satisfied: click~=8.0 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from fiona) (8.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from fiona) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from fiona) (0.7.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (1.38.1)
# Requirement already satisfied: click in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from geocoder) (8.5.0)
# Requirement already satisfied: future in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from geocoder) (1.0.0)
# Requirement already satisfied: ratelim in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from geocoder) (2.34.2)
# Requirement already satisfied: six in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from geocoder) (1.17.0)
# Requirement already satisfied: decorator in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from ratelim->geocoder) (5.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->geocoder) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->geocoder) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->geocoder) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/mateusalbuquerque/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages (from requests->geocoder) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext folium
# Out:
# The folium module is not an IPython extension.

# %%
# %load_ext folium_magic
# Out:
# The folium_magic extension is already loaded. To reload it, use:
#   %reload_ext folium_magic

# %% [markdown]
# Now we can call on the magic as `%folium_map`. The `-l` parameter lets us pass in comma separated latitude and longitude (no spaces between them) and the `-m` parameter lets us create a marker by passing in a comma separated latitude, longitude and marker label (the latter in quotes). The `-z` parameter sets the zoom level (by default it is set to 10).
#
# As well as using literal values, we can pass in values referenced via a variable we have already defined by prefixing the variable name with a `$`.
#
# So for example, the following are all valid `folium_magic` commands.
#
# - `%folium_map -l 52.0370037,-0.7098603`
# - `%folium_map -l $lat,$lon -z 14` (referencing the `lat` and `lon` variables defined above and increasing the zoom level)
# - `%folium_map -m 52.0370037,-0.7098603,"My Marker"`

# %%
# The folium_map magic will attempt to convert
# lat/lon string values to numeric float values
# %folium_map -m $lat,$lon -z 14
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 # The folium_map magic will attempt to convert
#       2 # lat/lon string values to numeric float values
# ----> 3 get_ipython().run_line_magic('folium_map', '-m $lat,$lon -z 14')
#
# File ~/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages/folium_magic/folium_magic.py:64, in FoliumMagic.folium_map(self, line)
#      62 if args.clustermarkers in self.shell.user_ns:
#      63     args.clustermarkers = self.shell.user_ns[args.clustermarkers]
# ---> 64 return folium_map(args, m, data)
#
# File ~/Documents/GitHub/ou.ac.uk-coursework/.venv/lib/python3.14/site-packages/folium_magic/folium_tools.py:234, in folium_map(args, m, data)
#     232     marker = [i for i in reader([get(args,'marker')])][0]
#     233     latlong = [float(x) for x in marker[:2]]
# --> 234     label = str(marker[2])
#     235 elif isinstance(marker, dict):
#     236     label = marker["label"] if "label" in marker else ""
#
# IndexError: list index out of range

# %% [markdown]
# ## Try it Yourself
#
# Modify the `params` definition above to use following cell tower data:
#
# - MCC: 234
# - MNC: 10
# - LAC: 1120
# - CID: 133246578
#
# Where is the cell tower located?

# %%
import requests

# 1. Update parameters with the requested cell tower data
params = {"mcc": 234, "mnc": 10, "lac": 1120, "cell_id": 133246578}

# 2. Query OpenCellID endpoint via GET request
url = f"https://opencellid.org/ajax/searchCell.php?mcc={params['mcc']}&mnc={params['mnc']}&lac={params['lac']}&cell_id={params['cell_id']}"
response = requests.get(url).json()

# 3. Extract lat and lon from the JSON response
lat = response["lat"]
lon = response["lon"]

print(f"Cell Tower Location: ({lat}, {lon})")

# 4. Render map using f-string magic
get_ipython().run_line_magic(
    "folium_map", f"-m {lat},{lon},'Cell Tower 133246578' -z 14"
)
# Out:
# Cell Tower Location: (52.024743, -0.709227)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ed1b4254dcd703719581aaae7363da0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ed1b4254dcd703719581aaae7363da0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ed1b4254dcd703719581aaae7363da0 = L.map(
#                 &quot;map_0ed1b4254dcd703719581aaae7363da0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed5d14f287769c93b18aa8b199e728b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed5d14f287769c93b18aa8b199e728b4.addTo(map_0ed1b4254dcd703719581aaae7363da0);
#
#
#             var marker_eae0899490378160b211ba76bd0ddaa1 = L.marker(
#                 [52.024743, -0.709227],
#                 {
# }
#             ).addTo(map_0ed1b4254dcd703719581aaae7363da0);
#
#
#         var popup_83eee108effe94e2f66a556e46ea6f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_758af728b7ae6c6018fbf42588c6d2f2 = $(`&lt;div id=&quot;html_758af728b7ae6c6018fbf42588c6d2f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cell Tower 133246578&lt;/div&gt;`)[0];
#                 popup_83eee108effe94e2f66a556e46ea6f1b.setContent(html_758af728b7ae6c6018fbf42588c6d2f2);
#
#
#
#         marker_eae0899490378160b211ba76bd0ddaa1.bindPopup(popup_83eee108effe94e2f66a556e46ea6f1b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# %folium_map -m $lat,$lon,"Cell Tower 133246578" -z 14
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ed1b4254dcd703719581aaae7363da0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ed1b4254dcd703719581aaae7363da0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ed1b4254dcd703719581aaae7363da0 = L.map(
#                 &quot;map_0ed1b4254dcd703719581aaae7363da0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed5d14f287769c93b18aa8b199e728b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed5d14f287769c93b18aa8b199e728b4.addTo(map_0ed1b4254dcd703719581aaae7363da0);
#
#
#             var marker_eae0899490378160b211ba76bd0ddaa1 = L.marker(
#                 [52.024743, -0.709227],
#                 {
# }
#             ).addTo(map_0ed1b4254dcd703719581aaae7363da0);
#
#
#         var popup_83eee108effe94e2f66a556e46ea6f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_758af728b7ae6c6018fbf42588c6d2f2 = $(`&lt;div id=&quot;html_758af728b7ae6c6018fbf42588c6d2f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cell Tower 133246578&lt;/div&gt;`)[0];
#                 popup_83eee108effe94e2f66a556e46ea6f1b.setContent(html_758af728b7ae6c6018fbf42588c6d2f2);
#
#
#
#         marker_eae0899490378160b211ba76bd0ddaa1.bindPopup(popup_83eee108effe94e2f66a556e46ea6f1b)
#         ;
#
#
#
#
#             tile_layer_ed5d14f287769c93b18aa8b199e728b4.addTo(map_0ed1b4254dcd703719581aaae7363da0);
#
#
#             var marker_12701253a2986ff5c424066acf9f6121 = L.marker(
#                 [52.024743, -0.709227],
#                 {
# }
#             ).addTo(map_0ed1b4254dcd703719581aaae7363da0);
#
#
#         var popup_e17d3a8082d79f48d989b9ec42d90ed0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9d2df001099fb2e9b5a0cd96edd3d1b = $(`&lt;div id=&quot;html_c9d2df001099fb2e9b5a0cd96edd3d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cell Tower 133246578&lt;/div&gt;`)[0];
#                 popup_e17d3a8082d79f48d989b9ec42d90ed0.setContent(html_c9d2df001099fb2e9b5a0cd96edd3d1b);
#
#
#
#         marker_12701253a2986ff5c424066acf9f6121.bindPopup(popup_e17d3a8082d79f48d989b9ec42d90ed0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
